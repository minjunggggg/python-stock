# %% [markdown]
# # 데이터 분석

# %%
  import pandas as pd

  df = pd.DataFrame({
      '이름': ['철수', '영희', '민수'],
      '점수': [85, 92, 78]
  })

  df
# Out:
#    이름  점수
# 0  철수  85
# 1  영희  92
# 2  민수  78

# %% [markdown]
# ## 데이터 로드

# %%
# df = pd.read_csv('../data/your_data.csv')
# df.head()

# %% [markdown]
# ## 탐색적 데이터 분석 (EDA)

# %%
# df.info()
# df.describe()
# df.isnull().sum()

# %% [markdown]
# ## 시각화

# %%
# 여기에 시각화 코드 작성
